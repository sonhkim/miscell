# %%
import csv
import pandas as pd
import os
import glob
import re

# %%
#pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_colwidth', None)

# %%
#root_dir = '/Users/songheekim/Documents/VerbSpec_eelbrain27/singletrialexport/2_or_3_word_trials_subspecificity/'

# %%
root_dir = '/Users/songheekim/Documents/VerbSpec_eelbrain27/singletrialexport_fixed/3_word_trials_full/'

# %%
roi_folders = ['left_BA21', 'LAG', 'Frankland-25', 'LATP']
sample_file = root_dir + 'LATP/ds_single_3word_fullanova_R0053.csv'

# %%
ds_sample = pd.read_csv(sample_file)
columns = ds_sample.columns.values.tolist()
#print (len(columns))

# %%
#ds_sample.head()
# Out:
#    index  Nmorph_o  Nmorph_s  Nmorph_v        RT       T  accept  \
# 0      0       2.0       2.0       1.0  0.637107  19.433    True
# 1      1       2.0       2.0       1.0  0.637107  19.433    True
# 2      2       2.0       2.0       1.0  0.637107  19.433    True
# 3      3       2.0       2.0       1.0  0.637107  19.433    True
# 4      4       2.0       2.0       1.0  0.637107  19.433    True
#
#   combinatoriness  condition  freq_o    freq_s    freq_v  index.1  len_o  \
# 0          3_word          3   9.023  5.232953  4.172194        0    7.0
# 1          3_word          3   9.023  5.232953  4.172194        0    7.0
# 2          3_word          3   9.023  5.232953  4.172194        0    7.0
# 3          3_word          3   9.023  5.232953  4.172194        0    7.0
# 4          3_word          3   9.023  5.232953  4.172194        0    7.0
#
#    len_s  len_v object_specificity  response              sentence  \
# 0    4.0    7.0            general         1  kids squeeze handles
# 1    4.0    7.0            general         1  kids squeeze handles
# 2    4.0    7.0            general         1  kids squeeze handles
# 3    4.0    7.0            general         1  kids squeeze handles
# 4    4.0    7.0            general         1  kids squeeze handles
#
#            spec2  srcm_at_t sub_hash sub_specificity subject  t      trial  \
# 0  all_but_spec2   0.381820     word         general   R0053  0  all_trial
# 1  all_but_spec2   0.326375     word         general   R0053  1  all_trial
# 2  all_but_spec2   0.445266     word         general   R0053  2  all_trial
# 3  all_but_spec2   0.454194     word         general   R0053  3  all_trial
# 4  all_but_spec2   0.454271     word         general   R0053  4  all_trial
#
#    trigger verb_hash verb_specificity word1    word2    word3
# 0        3      word        specific1  kids  squeeze  handles
# 1        3      word        specific1  kids  squeeze  handles
# 2        3      word        specific1  kids  squeeze  handles
# 3        3      word        specific1  kids  squeeze  handles
# 4        3      word        specific1  kids  squeeze  handles

# %%
ds_sample.head()
# Out:
#    index  Nmorph_o  Nmorph_s  Nmorph_v        RT       T  accept  \
# 0      0       2.0       2.0       1.0  0.637107  19.433    True
# 1      1       2.0       2.0       1.0  0.637107  19.433    True
# 2      2       2.0       2.0       1.0  0.637107  19.433    True
# 3      3       2.0       2.0       1.0  0.637107  19.433    True
# 4      4       2.0       2.0       1.0  0.637107  19.433    True
#
#   combinatoriness  condition  freq_o    freq_s    freq_v  index.1  len_o  \
# 0          3_word          3   9.023  5.232953  4.172194        0    7.0
# 1          3_word          3   9.023  5.232953  4.172194        0    7.0
# 2          3_word          3   9.023  5.232953  4.172194        0    7.0
# 3          3_word          3   9.023  5.232953  4.172194        0    7.0
# 4          3_word          3   9.023  5.232953  4.172194        0    7.0
#
#    len_s  len_v object_specificity  response              sentence  \
# 0    4.0    7.0            general         1  kids squeeze handles
# 1    4.0    7.0            general         1  kids squeeze handles
# 2    4.0    7.0            general         1  kids squeeze handles
# 3    4.0    7.0            general         1  kids squeeze handles
# 4    4.0    7.0            general         1  kids squeeze handles
#
#            spec2  srcm_at_t sub_hash sub_specificity subject  t      trial  \
# 0  all_but_spec2  -0.315789     word         general   R0053  0  all_trial
# 1  all_but_spec2  -0.175454     word         general   R0053  1  all_trial
# 2  all_but_spec2  -0.147332     word         general   R0053  2  all_trial
# 3  all_but_spec2  -0.165719     word         general   R0053  3  all_trial
# 4  all_but_spec2  -0.161875     word         general   R0053  4  all_trial
#
#    trigger verb_hash verb_specificity word1    word2    word3
# 0        3      word        specific1  kids  squeeze  handles
# 1        3      word        specific1  kids  squeeze  handles
# 2        3      word        specific1  kids  squeeze  handles
# 3        3      word        specific1  kids  squeeze  handles
# 4        3      word        specific1  kids  squeeze  handles

# %%
ds_sample.shape
# Out:
# (131528, 32)

# %%
for roi in roi_folders:
    print (roi)
    grand_df = pd.DataFrame(columns=columns)
    #filenames = os.listdir(root_dir + roi)
    filenames = [f for f in os.listdir(root_dir + roi) if not f.startswith('.')]
    filenames.sort()
    print (filenames)
    row_n = 0
    for filename in filenames: 
        #print (filename)
        with open(root_dir + roi + '/' + filename) as f:
            df = pd.read_csv(f)
            row_n += df.shape[0]
            print (filename, df.shape)
            grand_df = pd.concat([grand_df, df])
            #print (grand_df.shape)
            
    print ('row number check:', grand_df.shape[0] == row_n)
    grand_df.to_csv(root_dir + roi + '/' + 'grand_ds')
# Out:
# left_BA21
# ['ds_single_3word_fullanova_R0053.csv', 'ds_single_3word_fullanova_R0471.csv', 'ds_single_3word_fullanova_R0522.csv', 'ds_single_3word_fullanova_R0684.csv', 'ds_single_3word_fullanova_R0827.csv', 'ds_single_3word_fullanova_R0958.csv', 'ds_single_3word_fullanova_R0998.csv', 'ds_single_3word_fullanova_R1030.csv', 'ds_single_3word_fullanova_R1119.csv', 'ds_single_3word_fullanova_R1139.csv', 'ds_single_3word_fullanova_R1147.csv', 'ds_single_3word_fullanova_R1200.csv', 'ds_single_3word_fullanova_R1201.csv', 'ds_single_3word_fullanova_R1202.csv', 'ds_single_3word_fullanova_R1222.csv', 'ds_single_3word_fullanova_R1241.csv', 'ds_single_3word_fullanova_R1243.csv', 'ds_single_3word_fullanova_R1258.csv', 'ds_single_3word_fullanova_R1259.csv', 'ds_single_3word_fullanova_R1260.csv', 'ds_single_3word_fullanova_R1263.csv', 'ds_single_3word_fullanova_R1265.csv', 'ds_single_3word_fullanova_R1266.csv', 'ds_single_3word_fullanova_R1284.csv', 'ds_single_3word_fullanova_R1289.csv', 'ds_single_3word_fullanova_R1316.csv', 'ds_single_3word_fullanova_R1320.csv']
# ds_single_3word_fullanova_R0053.csv (131528, 32)
# ds_single_3word_fullanova_R0471.csv (133132, 32)
# ds_single_3word_fullanova_R0522.csv (131929, 32)
# ds_single_3word_fullanova_R0684.csv (129924, 32)
# ds_single_3word_fullanova_R0827.csv (119498, 32)
# ds_single_3word_fullanova_R0958.csv (132731, 32)
# ds_single_3word_fullanova_R0998.csv (130325, 32)
# ds_single_3word_fullanova_R1030.csv (126315, 32)
# ds_single_3word_fullanova_R1119.csv (129523, 32)
# ds_single_3word_fullanova_R1139.csv (128320, 32)
# ds_single_3word_fullanova_R1147.csv (127518, 32)
# ds_single_3word_fullanova_R1200.csv (122706, 32)
# ds_single_3word_fullanova_R1201.csv (129924, 32)
# ds_single_3word_fullanova_R1202.csv (131929, 32)
# ds_single_3word_fullanova_R1222.csv (114285, 32)
# ds_single_3word_fullanova_R1241.csv (134335, 32)
# ds_single_3word_fullanova_R1243.csv (131929, 32)
# ds_single_3word_fullanova_R1258.csv (131528, 32)
# ds_single_3word_fullanova_R1259.csv (131528, 32)
# ds_single_3word_fullanova_R1260.csv (129122, 32)
# ds_single_3word_fullanova_R1263.csv (132731, 32)
# ds_single_3word_fullanova_R1265.csv (132731, 32)
# ds_single_3word_fullanova_R1266.csv (125112, 32)
# ds_single_3word_fullanova_R1284.csv (132330, 32)
# ds_single_3word_fullanova_R1289.csv (132330, 32)
# ds_single_3word_fullanova_R1316.csv (128721, 32)
# ds_single_3word_fullanova_R1320.csv (130325, 32)
# row number check: True
# LAG
# ['ds_single_3word_fullanova_R0053.csv', 'ds_single_3word_fullanova_R0471.csv', 'ds_single_3word_fullanova_R0522.csv', 'ds_single_3word_fullanova_R0684.csv', 'ds_single_3word_fullanova_R0827.csv', 'ds_single_3word_fullanova_R0958.csv', 'ds_single_3word_fullanova_R0998.csv', 'ds_single_3word_fullanova_R1030.csv', 'ds_single_3word_fullanova_R1119.csv', 'ds_single_3word_fullanova_R1139.csv', 'ds_single_3word_fullanova_R1147.csv', 'ds_single_3word_fullanova_R1200.csv', 'ds_single_3word_fullanova_R1201.csv', 'ds_single_3word_fullanova_R1202.csv', 'ds_single_3word_fullanova_R1222.csv', 'ds_single_3word_fullanova_R1241.csv', 'ds_single_3word_fullanova_R1243.csv', 'ds_single_3word_fullanova_R1258.csv', 'ds_single_3word_fullanova_R1259.csv', 'ds_single_3word_fullanova_R1260.csv', 'ds_single_3word_fullanova_R1263.csv', 'ds_single_3word_fullanova_R1265.csv', 'ds_single_3word_fullanova_R1266.csv', 'ds_single_3word_fullanova_R1284.csv', 'ds_single_3word_fullanova_R1289.csv', 'ds_single_3word_fullanova_R1316.csv', 'ds_single_3word_fullanova_R1320.csv']
# ds_single_3word_fullanova_R0053.csv (131528, 32)
# ds_single_3word_fullanova_R0471.csv (133132, 32)
# ds_single_3word_fullanova_R0522.csv (131929, 32)
# ds_single_3word_fullanova_R0684.csv (129924, 32)
# ds_single_3word_fullanova_R0827.csv (119498, 32)

# %%
#### Previous attempt (with free orientation, not ms-by-ms)

# root_dir = '/Users/songheekim/Documents/VerbSpec_eelbrain27/export_to_R_Carbon/main_2_or_3/'

# subject = ["R0053", "R0471", "R0522", "R0684", "R0827", "R0958", "R0998", "R1030", "R1119", "R1139", "R1147", 
#            "R1200", "R1201", "R1202", "R1222", "R1241", "R1243", "R1258", "R1259", "R1260", "R1263", "R1265", 
#            "R1266", "R1284", "R1289", "R1316", "R1320"]
# len(subject)

# test_string = ['327_376', '313_374', '332_364', '360_401', '314_340', '535_575', '247_276', '345_389', '378_419', '341_391']
# #replace with re.match()

# ## create a list of all txt files
# allfile = os.listdir(root_dir)
# allfile = [a for a in allfile if a.startswith('main')]

# len(allfile)

# ### create a dictionary for each test
# #data = {k: [] for k in range(2)}
# test_dic = {k : [] for k in test_string}
# #test_dic

# for a in allfile:
#     testname = re.search('[0-9][0-9][0-9]_[0-9][0-9][0-9]', a, flags=0)
#     #print(testname.group(0))
#     test_dic[testname.group(0)].append(a)

# for v in test_dic.values():
#     v = v.sort()
    
# for v in test_dic.values():
#     print (len(v))

# test_dic

# #raw.columns.to_list()

# cols = ['in_c', 'trigger', 'sub_specificity', 'verb_specificity', 'sub_hash', 'combinatoriness', 'object_specificity', 'verb_hash', 'subject', 'sentence', 'word1', 'word2', 'word3',
#  'RT', 'freq_v', 'len_v', 'Nmorph_v', 'freq_s', 'len_s', 'Nmorph_s', 'freq_o', 'len_o', 'Nmorph_o', 'index']

# for k, v in test_dic.items():
#     print (k)
#     testname = v[0][:-10] #main_2_or_3_ba21_at_verb_327_376
#     df_list = []
#     allrowN = 0
#     for i in range(len(v)):
#         raw = pd.read_csv(root_dir + v[i], delimiter="\t")
#         df = raw[cols]
#         rowN = df.shape[0]
#         colN = df.shape[1]
#         allrowN += rowN
#         #print (v[i], df.shape)
#         #print ('i is ', i)
#         #print (v[i])
#         df_list.append(df)
#     print ('i is ', i)
#     all_df = pd.concat(df_list)
#     if not all_df.shape[0] == allrowN:
#         print (testname, 'the sum of row number is not equal to rows in ds_all!')
#     test_fn = '/Users/songheekim/Documents/VerbSpec_eelbrain27/export_to_R_Carbon/' + testname + '.csv'
#     print (test_fn)
#     all_df.to_csv(test_fn)
#     print ('test ', k, ' finished')
       
#     #print (all_df)
#     #print(len(df_list), '\n', df_list)
#     #break
